# %%
# !python3 "./drive/My Drive/vdsr_pytorch/datasets.py"

# %%
# !python3 "./drive/My Drive/vdsr_pytorch/utils.py"

# %%
# !python3 "./drive/My Drive/vdsr_pytorch/model.py"

# %%
# !python3 "./drive/My Drive/vdsr_pytorch/trainingmultiscale.py" \
--train_file2 "/content/drive/My Drive/vdsr_pytorch/datasets/training/91-image_x2.h5" \
--train_file3 "/content/drive/My Drive/vdsr_pytorch/datasets/training/91-image_x3.h5" \
--train_file4 "/content/drive/My Drive/vdsr_pytorch/datasets/training/91-image_x4.h5" \
--eval_file2 "/content/drive/My Drive/vdsr_pytorch/datasets/evaluation/Set5_x2.h5" \
--eval_file3 "/content/drive/My Drive/vdsr_pytorch/datasets/evaluation/Set5_x3.h5" \
--eval_file4 "/content/drive/My Drive/vdsr_pytorch/datasets/evaluation/Set5_x4.h5" \
--outputs_dir "/content/drive/My Drive/vdsr_pytorch/datasets/checkpointmulti"

# %%
# !python3 "./drive/My Drive/vdsr_pytorch/test.py" \
--weights_file "/content/drive/MyDrive/vdsr_pytorch/datasets/checkpointmulti/xmulti/epoch_9.pth" \
--image_file "/content/drive/MyDrive/srcnn_pytorch/dataset/input_bicubic_x3.bmp" \
--realimage_file "/content/drive/MyDrive/srcnn_pytorch/dataset/butterfly_GT.bmp" \
--scale 3
